# %%
# !pip install ccxt pandas matplotlib numpy
# Out:
# Collecting ccxt
#   Downloading ccxt-4.5.29-py2.py3-none-any.whl.metadata (136 kB)
# Requirement already satisfied: pandas in c:\users\kelvi\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\kelvi\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: numpy in c:\users\kelvi\anaconda3\lib\site-packages (2.3.4)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (80.9.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (2025.11.12)
# Requirement already satisfied: requests>=2.18.4 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (2.32.3)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (44.0.1)
# Requirement already satisfied: typing_extensions>=4.4.0 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (4.12.2)
# Requirement already satisfied: aiohttp>=3.10.11 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (3.11.10)
# Collecting aiodns>=1.1.1 (from ccxt)
#   Downloading aiodns-3.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: yarl>=1.7.2 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (1.18.0)
# Collecting coincurve==21.0.0 (from ccxt)
#   Downloading coincurve-21.0.0-cp313-cp313-win_amd64.whl.metadata (4.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kelvi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kelvi\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kelvi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kelvi\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kelvi\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kelvi\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kelvi\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\kelvi\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\kelvi\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kelvi\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Collecting pycares<5,>=4.9.0 (from aiodns>=1.1.1->ccxt)
#   Downloading pycares-4.11.0-cp313-cp313-win_amd64.whl.metadata (4.8 kB)
# Requirement already satisfied: cffi>=1.5.0 in c:\users\kelvi\anaconda3\lib\site-packages (from pycares<5,>=4.9.0->aiodns>=1.1.1->ccxt) (1.17.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (0.3.1)
# Requirement already satisfied: idna>=2.0 in c:\users\kelvi\anaconda3\lib\site-packages (from yarl>=1.7.2->ccxt) (3.7)
# Requirement already satisfied: pycparser in c:\users\kelvi\anaconda3\lib\site-packages (from cffi>=1.5.0->pycares<5,>=4.9.0->aiodns>=1.1.1->ccxt) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\kelvi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kelvi\anaconda3\lib\site-packages (from requests>=2.18.4->ccxt) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kelvi\anaconda3\lib\site-packages (from requests>=2.18.4->ccxt) (2.3.0)
# Downloading ccxt-4.5.29-py2.py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.2 MB 6.3 MB/s eta 0:00:01
#    ------------- -------------------------- 2.1/6.2 MB 5.4 MB/s eta 0:00:01
#    ------------------ --------------------- 2.9/6.2 MB 6.0 MB/s eta 0:00:01
#    ------------------------- -------------- 3.9/6.2 MB 5.6 MB/s eta 0:00:01
#    --------------------------------- ------ 5.2/6.2 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 5.1 MB/s eta 0:00:00
# Downloading coincurve-21.0.0-cp313-cp313-win_amd64.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 1.3/1.3 MB 7.3 MB/s eta 0:00:00
# Downloading aiodns-3.6.1-py3-none-any.whl (8.0 kB)
# Downloading pycares-4.11.0-cp313-cp313-win_amd64.whl (144 kB)
# Installing collected packages: coincurve, pycares, aiodns, ccxt
#
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ------------------------------ --------- 3/4 [ccxt]
#    ---------------------------------------- 4/4 [ccxt]
#
# Successfully installed aiodns-3.6.1 ccxt-4.5.29 coincurve-21.0.0 pycares-4.11.0

# %%
"""
Aave V3 Insolvency Simulation: Monte Carlo Approach
Simulating protocol risk under 10,000 extreme market volatility scenarios.
"""

import numpy as np
import matplotlib.pyplot as plt

class SolvencySimulator:
    def __init__(self, iterations=10000):
        self.iterations = iterations
        # Parameters derived from Dec 24 Flash Crash event
        self.initial_price = 86600
        self.crash_volatility = 0.72  # Observed -72.15% drop
        self.ltv_threshold = 0.85     # Aave V3 BTC Liquidation Threshold

    def run_simulation(self):
        print(f"[*] Running {self.iterations} Monte Carlo iterations...")
        
        # Generating normally distributed price shocks
        shocks = np.random.normal(loc=-0.05, scale=self.crash_volatility, size=self.iterations)
        
        # Identifying "Insolvent" iterations (where price drop > 15% for an 85% LTV loan)
        insolvency_mask = shocks < -0.15
        insolvency_prob = np.sum(insolvency_mask) / self.iterations
        
        print(f"[!] Simulation Complete.")
        print(f"    Probability of Liquidation Event: {insolvency_prob:.2%}")
        
        return shocks

    def plot_results(self, shocks):
        plt.figure(figsize=(10, 6))
        plt.hist(shocks, bins=100, color='royalblue', alpha=0.7, edgecolor='black')
        plt.axvline(x=-0.15, color='crimson', linestyle='--', label='Liquidation Threshold (LTV 85%)')
        plt.title("Monte Carlo Distribution: Potential Market Shocks")
        plt.xlabel("Price Change Percentage")
        plt.ylabel("Frequency")
        plt.legend()
        plt.show()

if __name__ == "__main__":
    # 1. Initialize the simulator
    simulator = SolvencySimulator()
    
    # 2. Run simulation (This automatically triggers aave_stress_test to fetch Binance data)
    results = simulator.run_simulation()
    
    # 3. UNCOMMENT THIS LINE TO SHOW THE PLOT (本地執行必須取消這行的註釋)
    simulator.plot_results(results)
# Out:
# [*] Running 10000 Monte Carlo iterations...
# [!] Simulation Complete.
#     Probability of Liquidation Event: 44.25%
