# %%
# !pip install ccxt pandas
# Out:
# Requirement already satisfied: ccxt in c:\users\kelvi\anaconda3\lib\site-packages (4.5.29)
# Requirement already satisfied: pandas in c:\users\kelvi\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (80.9.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (2025.11.12)
# Requirement already satisfied: requests>=2.18.4 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (2.32.3)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (44.0.1)
# Requirement already satisfied: typing_extensions>=4.4.0 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (4.12.2)
# Requirement already satisfied: aiohttp>=3.10.11 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (3.11.10)
# Requirement already satisfied: aiodns>=1.1.1 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (3.6.1)
# Requirement already satisfied: yarl>=1.7.2 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (1.18.0)
# Requirement already satisfied: coincurve==21.0.0 in c:\users\kelvi\anaconda3\lib\site-packages (from ccxt) (21.0.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\kelvi\anaconda3\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kelvi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kelvi\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kelvi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pycares<5,>=4.9.0 in c:\users\kelvi\anaconda3\lib\site-packages (from aiodns>=1.1.1->ccxt) (4.11.0)
# Requirement already satisfied: cffi>=1.5.0 in c:\users\kelvi\anaconda3\lib\site-packages (from pycares<5,>=4.9.0->aiodns>=1.1.1->ccxt) (1.17.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\kelvi\anaconda3\lib\site-packages (from aiohttp>=3.10.11->ccxt) (0.3.1)
# Requirement already satisfied: idna>=2.0 in c:\users\kelvi\anaconda3\lib\site-packages (from yarl>=1.7.2->ccxt) (3.7)
# Requirement already satisfied: pycparser in c:\users\kelvi\anaconda3\lib\site-packages (from cffi>=1.5.0->pycares<5,>=4.9.0->aiodns>=1.1.1->ccxt) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\kelvi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kelvi\anaconda3\lib\site-packages (from requests>=2.18.4->ccxt) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kelvi\anaconda3\lib\site-packages (from requests>=2.18.4->ccxt) (2.3.0)

# %%
import ccxt
import pandas as pd
from datetime import datetime

# --- PART 1: Data Acquisition & Anomaly Detection ---
def get_crash_params():
    exchange = ccxt.binance()
    # 12/24 Start Time in UTC
    since = int(datetime(2025, 12, 24, 0, 0).timestamp() * 1000)
    
    print("Scanning Binance for flash crash anomalies...")
    ohlcv = exchange.fetch_ohlcv('BTC/USD1', timeframe='1m', since=since, limit=1440)
    df = pd.DataFrame(ohlcv, columns=['ts', 'open', 'high', 'low', 'close', 'vol'])
    
    # Identify the exact second of the -72% drop
    crash_row = df.loc[((df['low'] - df['open']) / df['open']) < -0.5].iloc[0]
    
    return crash_row['open'], crash_row['low']

# --- PART 2: Stress Test Logic ---
def run_stress_test(market_p, crash_p, collateral_usd=1000000, debt_usd=800000):
    drop_pct = (crash_p - market_p) / market_p
    liquidation_threshold = 0.85
    
    # Calculate HF, the (Simulated) Health Factor, if Oracle adopted crash price
    crash_hf = (collateral_usd * (1 + drop_pct) * liquidation_threshold) / debt_usd
    
    print(f"\n--- Stress Test for ${collateral_usd/1e6}M Position ---")
    print(f"Detected Drop: {drop_pct:.2%} (from ${market_p:,.2} to ${crash_p:,.2})")
    print(f"Resulting Health Factor: {crash_hf:.2f}")
    
    if crash_hf < 1.0:
        print(">>> STATUS: LIQUIDATION TRIGGERED.")

# --- PART 3: Execution ---
m_price, c_price = get_crash_params()
run_stress_test(m_price, c_price)
# Out:
# Scanning Binance for flash crash anomalies...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 36
#      33         print(">>> STATUS: LIQUIDATION TRIGGERED.")
#      35 # --- PART 3: Execution ---
# ---> 36 m_price, c_price = get_crash_params()
#      37 run_stress_test(m_price, c_price)
#
# Cell In[8], line 16, in get_crash_params()
#      13 df = pd.DataFrame(ohlcv, columns=['ts', 'open', 'high', 'low', 'close', 'vol'])
#      15 # Identify the exact second of the -72% drop
# ---> 16 crash_row = df.loc[((df['low'] - df['open']) / df['open']) < -0.5].iloc[0]
#      18 return crash_row['open'], crash_row['low']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
